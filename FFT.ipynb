# %%
import pandas as pd
from macdlib import *
import matplotlib.pyplot as plt
# %matplotlib inline

STOCK_CODE='SZ.002405'

prepare_csv_data([STOCK_CODE],n_days=90)
compute_df_bar([STOCK_CODE])
# Out:
# 2019-09-14 12:17:01,923 [open_context_base.py] _socket_reconnect_and_wait_ready:256: Start connecting: host=cxu-pc; port=11111;
# 2019-09-14 12:17:01,970 [open_context_base.py] on_connected:344: Connected : conn_id=1;
# 2019-09-14 12:17:01,993 [open_context_base.py] _handle_init_connect:444: InitConnect ok: conn_id=1; info={'server_version': 203, 'login_user_id': 1509176, 'conn_id': 6578491617003322454, 'conn_key': 'A5F76A75457F4B5B', 'keep_alive_interval': 10, 'is_encrypt': False};

# %%
fname = df_file_name(STOCK_CODE, KLType.K_60M)
df60 = pd.read_csv(fname, index_col=0)

df60
# Out:
#           code             time_key  close      diff  macd_bar        ma5  \
# 0    SZ.002405  2019-06-17 10:30:00  15.49  0.000000  0.000000  15.490000
# 1    SZ.002405  2019-06-17 11:30:00  15.68  0.015157  0.024251  15.585000
# 2    SZ.002405  2019-06-17 14:00:00  15.67  0.026061  0.036848  15.613333
# 3    SZ.002405  2019-06-17 15:00:00  15.64  0.031914  0.038843  15.620000
# 4    SZ.002405  2019-06-18 10:30:00  16.07  0.070439  0.092713  15.765000
# 5    SZ.002405  2019-06-18 11:30:00  16.14  0.105403  0.130113  15.880000
# 6    SZ.002405  2019-06-18 14:00:00  15.98  0.118831  0.125577  15.957500
# 7    SZ.002405  2019-06-18 15:00:00  16.02  0.131189  0.120234  16.052500
# 8    SZ.002405  2019-06-19 10:30:00  16.28  0.160117  0.142471  16.105000
# 9    SZ.002405  2019-06-19 11:30:00  16.16  0.171384  0.132004  16.110000
# 10   SZ.002405  2019-06-19 14:00:00  16.24  0.184640  0.126813  16.175000
# 11   SZ.002405  2019-06-19 15:00:00  16.05  0.177765  0.090450  16.182500
# 12   SZ.002405  2019-06-20 10:30:00  16.27  0.187902  0.088580  16.180000
# 13   SZ.002405  2019-06-20 11:30:00  16.71  0.228803  0.136306  16.317500
# 14   SZ.002405  2019-06-20 14:00:00  16.49  0.240691  0.128065  16.380000
# 15   SZ.002405  2019-06-20 15:00:00  16.50  0.248059  0.114241  16.492500
# 16   SZ.002405  2019-06-21 10:30:00  16.86  0.279723  0.142055  16.640000
# 17   SZ.002405  2019-06-21 11:30:00  16.79  0.295759  0.139302  16.660000
# 18   SZ.002405  2019-06-21 14:00:00  16.56  0.286605  0.096795  16.677500
# 19   SZ.002405  2019-06-21 15:00:00  16.50  0.271381  0.053077  16.677500
# 20   SZ.002405  2019-06-24 10:30:00  16.29  0.239608 -0.008375  16.535000
# 21   SZ.002405  2019-06-24 11:30:00  16.13  0.199221 -0.071319  16.370000
# 22   SZ.002405  2019-06-24 14:00:00  16.16  0.167701 -0.107487  16.270000
# 23   SZ.002405  2019-06-24 15:00:00  16.25  0.148275 -0.117072  16.207500
# 24   SZ.002405  2019-06-25 10:30:00  16.11  0.120197 -0.138583  16.162500
# 25   SZ.002405  2019-06-25 11:30:00  15.71  0.064920 -0.199309  16.057500
# 26   SZ.002405  2019-06-25 14:00:00  15.90  0.036028 -0.205674  15.992500
# 10   16.022222    0.15
# 11   16.064444    0.12
# 12   16.134444    0.05
# 13   16.205556    0.11
# 14   16.244444    0.14
# 15   16.302222    0.19
# 16   16.395556    0.24
# 17   16.452222    0.21
# 18   16.496667    0.18
# 19   16.525556    0.15
# 20   16.552222   -0.02
# 21   16.536667   -0.17
# 22   16.475556   -0.21
# 23   16.448889   -0.24
# 24   16.405556   -0.24
# 25   16.277778   -0.22
# 26   16.178889   -0.19
# 27   16.113333   -0.19
# 28   16.065556   -0.15
# 29   16.055556   -0.02
# ..         ...     ...
# 226  16.052222    0.19
# 227  16.126667    0.17
# 228  16.201111    0.12
# 229  16.205556    0.05
# 230  16.217778   -0.00
# 231  16.241111   -0.04
# 232  16.307778    0.00
# 233  16.381111    0.14
# 234  16.445556    0.28
# 235  16.502222    0.33
# 236  16.543333    0.29
# 237  16.612222    0.23
# 238  16.691111    0.11
# 239  16.802222    0.09
# 240  16.916667    0.12
# 241  17.008889    0.20
# 242  17.087778    0.33
# 243  17.195556    0.41
# 244  17.264444    0.35
# 245  17.328889    0.22
# 246  17.380000    0.12
# 247  17.462222   -0.06
# 248  17.494444   -0.08
# 249  17.497778   -0.08
# 250  17.447778   -0.09
# 251  17.396667   -0.13
# 252  17.335556   -0.08
# 253  17.348889   -0.07
# 254  17.352222   -0.02
# 255  17.361111    0.06
#
# [256 rows x 8 columns]

# %%
red_areas, blue_areas = find_successive_bar_areas(df60, 'macd_bar')
blue_areas
# Out:
# [(0, 0),
#  (20, 34),
#  (36, 39),
#  (50, 79),
#  (103, 103),
#  (123, 123),
#  (132, 162),
#  (193, 204),
#  (216, 231),
#  (248, 255)]

# %%
red_areas
# Out:
# [(0, 19),
#  (35, 35),
#  (40, 49),
#  (80, 102),
#  (104, 122),
#  (124, 131),
#  (163, 192),
#  (205, 215),
#  (232, 247)]

# %%
df_red = do_bar_wave_tag(df60, 'macd_bar', red_areas)
df_red[df_red._macd_bar_tag!=0].index
# Out:
# Int64Index([  0,   5,   7,   8,  12,  15,  16,  19,  40,  44,  49,  80,  85,
#              95,  99, 102, 104, 110, 112, 113, 122, 124, 126, 128, 163, 170,
#             171, 176, 179, 182, 192, 205, 208, 215, 232, 234, 238, 243, 247],
#            dtype='int64')

# %%
df_red[df_red._macd_bar_tag!=0]
# Out:
#      macd_bar  _macd_bar_tag
# 0    0.000000              1
# 5    0.130113              2
# 7    0.120234              1
# 8    0.142471              2
# 12   0.088580              1
# 15   0.114241              1
# 16   0.142055              2
# 19   0.053077              1
# 40   0.041590              1
# 44   0.185600              2
# 49   0.016788              1
# 80   0.023511              1
# 85   0.173346              2
# 95   0.011685              1
# 99   0.051427              2
# 102  0.015185              1
# 104  0.012930              1
# 110  0.185298              2
# 112  0.178070              1
# 113  0.195340              2
# 122  0.007402              1
# 124  0.020533              1
# 126  0.041222              2
# 128  0.031392              1
# 163  0.056757              1
# 170  0.219463              2
# 171  0.197555              1
# 176  0.240845              2
# 179  0.204789              1
# 182  0.238206              2
# 192  0.010567              1
# 205  0.116131              1
# 208  0.197897              2
# 215  0.000674              1
# 232  0.019018              1
# 234  0.100315              2
# 238  0.053032              1
# 243  0.195903              2
# 247  0.020343              1

# %%
df_blue = do_bar_wave_tag(df60, 'macd_bar', blue_areas)
df_blue['_macd_bar_tag']*=-1
df_blue[df_blue._macd_bar_tag!=0]
# Out:
#      macd_bar  _macd_bar_tag
# 20   0.008375             -1
# 26   0.205674             -2
# 34   0.006955             -1
# 50   0.023548             -1
# 57   0.132537             -2
# 59   0.101633             -1
# 63   0.361854             -2
# 73   0.059241             -1
# 75   0.198223             -2
# 79   0.038746             -1
# 132  0.004408             -1
# 138  0.148238             -2
# 142  0.027125             -1
# 145  0.193799             -2
# 147  0.159025             -1
# 149  0.159630             -2
# 155  0.064663             -1
# 158  0.133981             -2
# 162  0.036974             -1
# 193  0.009700             -1
# 200  0.195755             -2
# 204  0.001240             -1
# 216  0.013502             -1
# 219  0.164690             -2
# 227  0.008666             -1
# 230  0.065568             -2
# 231  0.047646             -1
# 248  0.013837             -1
# 251  0.128182             -2
# 255  0.088260             -1

# %%
df_red = do_bar_wave_tag(df60, 'macd_bar', red_areas)
df_red[df_red._macd_bar_tag!=0]
# Out:
#      macd_bar  _macd_bar_tag
# 0    0.000000              1
# 5    0.130113              2
# 7    0.120234              1
# 8    0.142471              2
# 12   0.088580              1
# 15   0.114241              1
# 16   0.142055              2
# 19   0.053077              1
# 40   0.041590              1
# 44   0.185600              2
# 49   0.016788              1
# 80   0.023511              1
# 85   0.173346              2
# 95   0.011685              1
# 99   0.051427              2
# 102  0.015185              1
# 104  0.012930              1
# 110  0.185298              2
# 112  0.178070              1
# 113  0.195340              2
# 122  0.007402              1
# 124  0.020533              1
# 126  0.041222              2
# 128  0.031392              1
# 163  0.056757              1
# 170  0.219463              2
# 171  0.197555              1
# 176  0.240845              2
# 179  0.204789              1
# 182  0.238206              2
# 192  0.010567              1
# 205  0.116131              1
# 208  0.197897              2
# 215  0.000674              1
# 232  0.019018              1
# 234  0.100315              2
# 238  0.053032              1
# 243  0.195903              2
# 247  0.020343              1

# %%
df60['_macd_bar_tag'] = df_red['_macd_bar_tag']|df_blue['_macd_bar_tag']

df60[df60._macd_bar_tag!=0]
# Out:
#           code             time_key  close      diff  macd_bar      ma5  \
# 0    SZ.002405  2019-06-17 10:30:00  15.49  0.000000  0.000000  15.4900
# 5    SZ.002405  2019-06-18 11:30:00  16.14  0.105403  0.130113  15.8800
# 7    SZ.002405  2019-06-18 15:00:00  16.02  0.131189  0.120234  16.0525
# 8    SZ.002405  2019-06-19 10:30:00  16.28  0.160117  0.142471  16.1050
# 12   SZ.002405  2019-06-20 10:30:00  16.27  0.187902  0.088580  16.1800
# 15   SZ.002405  2019-06-20 15:00:00  16.50  0.248059  0.114241  16.4925
# 16   SZ.002405  2019-06-21 10:30:00  16.86  0.279723  0.142055  16.6400
# 19   SZ.002405  2019-06-21 15:00:00  16.50  0.271381  0.053077  16.6775
# 20   SZ.002405  2019-06-24 10:30:00  16.29  0.239608 -0.008375  16.5350
# 26   SZ.002405  2019-06-25 14:00:00  15.90  0.036028 -0.205674  15.9925
# 34   SZ.002405  2019-06-27 14:00:00  16.38  0.038920 -0.006955  16.2200
# 40   SZ.002405  2019-07-01 10:30:00  16.77  0.056518  0.041590  16.2375
# 227  SZ.002405  2019-09-03 15:00:00  16.40  0.193867 -0.008666  16.3000
# 230  SZ.002405  2019-09-04 14:00:00  16.10  0.150170 -0.065568  16.2175
# 231  SZ.002405  2019-09-04 15:00:00  16.33  0.153175 -0.047646  16.2000
# 232  SZ.002405  2019-09-05 10:30:00  16.77  0.188884  0.019018  16.3125
# 234  SZ.002405  2019-09-05 14:00:00  16.91  0.251054  0.100315  16.7250
# 238  SZ.002405  2019-09-06 14:00:00  16.76  0.264731  0.053032  16.8050
# 243  SZ.002405  2019-09-09 15:00:00  17.88  0.422800  0.195903  17.6100
# 247  SZ.002405  2019-09-10 15:00:00  17.50  0.369165  0.020343  17.4050
# 248  SZ.002405  2019-09-11 10:30:00  17.39  0.350346 -0.013837  17.4100
# 251  SZ.002405  2019-09-11 15:00:00  17.14  0.260394 -0.128182  17.2675
# 255  SZ.002405  2019-09-12 15:00:00  17.48  0.228249 -0.088260  17.4200
#
#           ma10  em_bar  _macd_bar_tag
# 0    15.490000    0.00              1
# 5    15.781667    0.10              2
# 7    15.836250    0.22              1
# 8    15.885556    0.22              2
# 12   16.134444    0.05              1
# 15   16.302222    0.19              1
# 16   16.395556    0.24              2
# 19   16.525556    0.15              1
# 20   16.552222   -0.02             -1
# 26   16.178889   -0.19             -2
# 34   16.128889    0.09             -1
# 40   16.250000   -0.01              1
# 44   16.518889    0.39              2
# 49   16.844444   -0.08              1
# 50   16.823333   -0.13             -1
# 57   16.456667   -0.09             -2
# 59   16.413333   -0.04             -1
# 63   15.901111   -0.58             -2
# 73   15.018889   -0.05             -1
# 75   14.772222   -0.31             -2
# 79   14.471111   -0.11             -1
# 80   14.431111    0.01              1
# 85   14.605556    0.10              2
# 95   14.485556   -0.19              1
# 99   14.382222    0.04              2
# 102  14.313333   -0.05              1
# 104  14.291111   -0.10              1
# 110  14.422222    0.29              2
# 112  14.573333    0.23              1
# 113  14.656667    0.18              2
# ..         ...     ...            ...
# 149  14.290000   -0.18             -2
# 155  13.951111   -0.06             -1
# 158  13.732222   -0.20             -2
# 162  13.513333   -0.12             -1
# 163  13.523333    0.04              1
# 170  13.888889    0.19              2
# 171  13.937778    0.20              1
# 176  14.300000    0.16              2
# 179  14.476667    0.22              1
# 182  14.803333    0.21              2
# 192  15.308889    0.04              1
# 193  15.303333    0.07             -1
# 200  15.181111   -0.20             -2
# 204  15.125556    0.14             -1
# 205  15.248889    0.32              1
# 208  15.615556    0.57              2
# 215  16.200000   -0.03              1
# 216  16.205556   -0.04             -1
# 219  16.062222   -0.16             -2
# 227  16.126667    0.17             -1
# 230  16.217778   -0.00             -2
# 231  16.241111   -0.04             -1
# 232  16.307778    0.00              1
# 234  16.445556    0.28              2
# 238  16.691111    0.11              1
# 243  17.195556    0.41              2
# 247  17.462222   -0.06              1
# 248  17.494444   -0.08             -1
# 251  17.396667   -0.13             -2
# 255  17.361111    0.06             -1
#
# [69 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

from matplotlib.dates import DateFormatter
# %matplotlib inline

fig, ax = plt.subplots(1,1, figsize=(20, 7))




df60['colors'] = 'r'
df60.loc[df60.macd_bar<0,'colors'] = 'g'

x_red = df60[df60.macd_bar>0].index
y_red = df60[df60.macd_bar>0]['macd_bar']

x_green = df60[df60.macd_bar<=0].index
y_green = df60[df60.macd_bar<=0]['macd_bar']


ax.bar(x_red, y_red, color='r')
ax.bar(x_green, y_green, color='g')
ax.set_xticklabels(df60['time_key'].array)
ax.xaxis.set_tick_params(rotation=90)

ax.set_title("df60")
# Out:
# Text(0.5, 1.0, 'df60')

# %%
colors = tuple(np.where(df60["macd_bar"]>0, 'r', 'g'))

df60['macd_bar'].plot(kind='bar', color= colors, figsize=(20,7) )

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from example.commons import Faker

def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        #.add_yaxis("商家A", Faker.values())
        #.add_yaxis("商家B", Faker.values())
        .add_yaxis("上架C",[-111,38,22,33,22,-10,-50])
        #.set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
    )
    return c

def new_bar(x, y, title) -> Bar:
    items = []
    for idx, value in zip(x,y):
        if value>=0:
            items.append(
            opts.BarItem(
                    name=idx,
                    value=value,
                    itemstyle_opts=opts.ItemStyleOpts(color="red"),
                )
            )
        else:
            items.append(
            opts.BarItem(
                    name=idx,
                    value=value,
                    itemstyle_opts=opts.ItemStyleOpts(color="green"),
                )
            )
            
    c = (
        Bar()
        .add_xaxis(x)
        .add_yaxis(title,items)
        .set_global_opts(title_opts=opts.TitleOpts(title=title, subtitle="-"))
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
#             markpoint_opts=opts.MarkPointOpts(
#                 data=[
#                     opts.MarkPointItem(type_="max", name="最大值"),
#                     opts.MarkPointItem(type_="min", name="最小值"),
#                     #opts.MarkPointItem(type_="average", name="平均值"),
#                 ]
#             ),
        )
    )
    
    return c


b = new_bar(df60['time_key'].tolist(), df60['macd_bar'].tolist(), 'MACD_BAR')
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="99404fd0a97e4858a2ad6105259ba05d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_99404fd0a97e4858a2ad6105259ba05d = echarts.init(
#                     document.getElementById('99404fd0a97e4858a2ad6105259ba05d'), 'white', {renderer: 'canvas'});
#                 var option_99404fd0a97e4858a2ad6105259ba05d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "MACD_BAR",
#             "data": [
#                 {
#                     "name": "2019-06-17 10:30:00",
#                     "value": 0.0,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-17 11:30:00",
#                     "value": 0.02425071225071349,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-17 14:00:00",
#                     "value": 0.036847700911520745,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-17 15:00:00",
#                     "value": 0.038843316518573145,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-18 10:30:00",
#                     "value": 0.09271330234725217,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-18 11:30:00",
#                     "value": 0.13011315446547314,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-18 14:00:00",
#                     "value": 0.1255766042508044,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-18 15:00:00",
#                     "value": 0.1202337939999792,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-19 10:30:00",
#                     "value": 0.14247144946272655,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-19 11:30:00",
#                     "value": 0.13200412611322565,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-19 14:00:00",
#                     "value": 0.12681287145330686,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-19 15:00:00",
#                     "value": 0.09045011793381537,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-20 10:30:00",
#                     "value": 0.08858019866306044,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-20 11:30:00",
#                     "value": 0.13630562380932135,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-20 14:00:00",
#                     "value": 0.12806462003821414,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-20 15:00:00",
#                     "value": 0.11424119008915552,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-21 10:30:00",
#                     "value": 0.14205543649291508,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-21 11:30:00",
#                     "value": 0.1393023390636169,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-21 14:00:00",
#                     "value": 0.09679539399379412,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-21 15:00:00",
#                     "value": 0.05307718109826276,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-06-24 10:30:00",
#                     "value": -0.008374722820790381,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-24 11:30:00",
#                     "value": -0.07131949629770756,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-24 14:00:00",
#                     "value": -0.10748703864561247,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-24 15:00:00",
#                     "value": -0.11707206458752685,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-25 10:30:00",
#                     "value": -0.13858251577639902,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-25 11:30:00",
#                     "value": -0.1993093066798964,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-25 14:00:00",
#                     "value": -0.20567363131345595,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-06-25 15:00:00",
#                     "value": -0.1924784543581355,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019

# %%
df60.shape[0]
# Out:
# 256

# %%
import numpy as np
x = np.arange(1,100)
y = np.sin(np.arange(1,100))
colors = np.array([(1,0,0)]*len(y))
colors[y >= 0] = (0,0,1)
plt.bar(x,y,color = colors)
#https://stackoverflow.com/questions/31574403/bar-graph-color-dependent-on-value-in-matplotlib
# Out:
# <BarContainer object of 99 artists>

# %%
x = np.arange(1,100)
y = np.sin(3*np.arange(1,100))
colors = np.array([(1,0,0)]*len(y))
colors[y >= 0] = (0,0,1)
mult = np.reshape(np.repeat(np.abs(y)/np.max(np.abs(y)),3),(len(y),3))
colors =  mult*colors
plt.bar(x,y,color = colors)
# Out:
# <BarContainer object of 99 artists>

# %%
import numpy as np
import matplotlib.pylab as pl

array = np.random.randn(100)
greater_than_zero = array > 0
lesser_than_zero = array < 0
cax = pl.subplot(111)
cax.bar(np.arange(len(array))[greater_than_zero], array[greater_than_zero], color='b')
cax.bar(np.arange(len(array))[lesser_than_zero], array[lesser_than_zero], color='r')
# Out:
# <BarContainer object of 52 artists>

# %%
df60[df60._macd_bar_tag==-2]
# Out:
#           code             time_key  close      diff  macd_bar      ma5  \
# 26   SZ.002405  2019-06-25 14:00:00  15.90  0.036028 -0.205674  15.9925
# 57   SZ.002405  2019-07-05 11:30:00  16.30  0.007334 -0.132537  16.3625
# 63   SZ.002405  2019-07-08 15:00:00  15.06 -0.271995 -0.361854  15.3225
# 75   SZ.002405  2019-07-11 15:00:00  14.00 -0.490246 -0.198223  14.4625
# 138  SZ.002405  2019-08-02 14:00:00  14.50 -0.035698 -0.148238  14.6025
# 145  SZ.002405  2019-08-06 11:30:00  13.92 -0.138343 -0.193799  14.3175
# 149  SZ.002405  2019-08-07 11:30:00  13.96 -0.203686 -0.159630  14.1075
# 158  SZ.002405  2019-08-09 14:00:00  13.28 -0.316425 -0.133981  13.5350
# 200  SZ.002405  2019-08-26 10:30:00  14.74  0.111182 -0.195755  14.9775
# 219  SZ.002405  2019-08-30 15:00:00  15.65  0.190968 -0.164690  15.9050
# 230  SZ.002405  2019-09-04 14:00:00  16.10  0.150170 -0.065568  16.2175
# 251  SZ.002405  2019-09-11 15:00:00  17.14  0.260394 -0.128182  17.2675
#
#           ma10  em_bar  _macd_bar_tag colors
# 26   16.178889   -0.19             -2      g
# 57   16.456667   -0.09             -2      g
# 63   15.901111   -0.58             -2      g
# 75   14.772222   -0.31             -2      g
# 138  14.798889   -0.20             -2      g
# 145  14.527778   -0.21             -2      g
# 149  14.290000   -0.18             -2      g
# 158  13.732222   -0.20             -2      g
# 200  15.181111   -0.20             -2      g
# 219  16.062222   -0.16             -2      g
# 230  16.217778   -0.00             -2      g
# 251  17.396667   -0.13             -2      g
