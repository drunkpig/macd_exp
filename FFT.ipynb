# %%
import pandas as pd
from macdlib import *
import matplotlib.pyplot as plt
# %matplotlib inline

STOCK_CODE='SZ.002405'
#prepare_csv_data([STOCK_CODE])
compute_df_bar([STOCK_CODE])

# %%
fname = df_file_name(STOCK_CODE, KLType.K_60M)
df60 = pd.read_csv(fname, index_col=0)

df60
# Out:
#          code             time_key  close      diff  macd_bar        ma5  \
# 0   SZ.002405  2019-08-02 10:30:00  14.57  0.000000  0.000000  14.570000
# 1   SZ.002405  2019-08-02 11:30:00  14.44 -0.010370 -0.016593  14.505000
# 2   SZ.002405  2019-08-02 14:00:00  14.50 -0.013591 -0.018427  14.503333
# 3   SZ.002405  2019-08-02 15:00:00  14.51 -0.015161 -0.017254  14.505000
# 4   SZ.002405  2019-08-05 10:30:00  15.12  0.032442  0.062362  14.642500
# 5   SZ.002405  2019-08-05 11:30:00  14.91  0.052616  0.082168  14.760000
# 6   SZ.002405  2019-08-05 14:00:00  14.78  0.057452  0.073472  14.830000
# 7   SZ.002405  2019-08-05 15:00:00  14.65  0.050216  0.047200  14.865000
# 8   SZ.002405  2019-08-06 10:30:00  13.92 -0.014259 -0.065401  14.565000
# 9   SZ.002405  2019-08-06 11:30:00  13.92 -0.064612 -0.132884  14.317500
# 10  SZ.002405  2019-08-06 14:00:00  14.20 -0.080989 -0.132511  14.172500
# 11  SZ.002405  2019-08-06 15:00:00  14.23 -0.090504 -0.121233  14.067500
# 12  SZ.002405  2019-08-07 10:30:00  14.04 -0.112084 -0.131515  14.097500
# 13  SZ.002405  2019-08-07 11:30:00  13.96 -0.134096 -0.140431  14.107500
# 14  SZ.002405  2019-08-07 14:00:00  13.98 -0.148219 -0.134940  14.052500
# 15  SZ.002405  2019-08-07 15:00:00  13.80 -0.171953 -0.145927  13.945000
# 16  SZ.002405  2019-08-08 10:30:00  13.91 -0.179814 -0.129319  13.912500
# 17  SZ.002405  2019-08-08 11:30:00  13.86 -0.187912 -0.116412  13.887500
# 18  SZ.002405  2019-08-08 14:00:00  13.90 -0.188924 -0.094750  13.867500
# 19  SZ.002405  2019-08-08 15:00:00  13.88 -0.189160 -0.076177  13.887500
# 20  SZ.002405  2019-08-09 10:30:00  13.70 -0.201548 -0.080762  13.835000
# 21  SZ.002405  2019-08-09 11:30:00  13.28 -0.242461 -0.130071  13.690000
# 22  SZ.002405  2019-08-09 14:00:00  13.28 -0.271752 -0.150923  13.535000
# 23  SZ.002405  2019-08-09 15:00:00  13.31 -0.289211 -0.148672  13.392500
# 24  SZ.002405  2019-08-12 10:30:00  13.35 -0.296403 -0.130445  13.305000
# 25  SZ.002405  2019-08-12 11:30:00  13.35 -0.298660 -0.107967  13.322500
# 26  SZ.002405  2019-08-12 14:00:00  13.57 -0.279475 -0.055677  13.395000
# 27  SZ.002405  2019-08-12 15:00:00  13.99 -0.227755  0.038211  13.565000
# 28  SZ.002405  2019-08-13 10:30:00  13.80 -0.199794  0.075305  13.677500
# 29  SZ.002405  2019-08-13 11:30:00  13.63 -0.189172  0.077239  13.747500
# ..        ...                  ...    ...       ...       ...        ...
# 17  13.988889   -0.10
# 18  13.986667   -0.12
# 19  13.951111   -0.06
# 20  13.892222   -0.06
# 21  13.807778   -0.12
# 22  13.732222   -0.20
# 23  13.657778   -0.27
# 24  13.607778   -0.30
# 25  13.545556   -0.22
# 26  13.513333   -0.12
# 27  13.523333    0.04
# 28  13.514444    0.16
# 29  13.506667    0.24
# ..        ...     ...
# 54  15.280000   -0.03
# 55  15.286667   -0.01
# 56  15.308889    0.04
# 57  15.303333    0.07
# 58  15.300000    0.07
# 59  15.315556    0.07
# 60  15.314444   -0.00
# 61  15.305556   -0.06
# 62  15.280000   -0.12
# 63  15.242222   -0.16
# 64  15.181111   -0.20
# 65  15.132222   -0.17
# 66  15.091111   -0.14
# 67  15.038889   -0.13
# 68  15.125556    0.14
# 69  15.248889    0.32
# 70  15.350000    0.48
# 71  15.476667    0.67
# 72  15.615556    0.57
# 73  15.778889    0.39
# 74  15.906667    0.31
# 75  16.048889    0.19
# 76  16.197778    0.02
# 77  16.202222    0.02
# 78  16.201111    0.03
# 79  16.200000   -0.03
# 80  16.205556   -0.04
# 81  16.175556   -0.05
# 82  16.122222   -0.13
# 83  16.062222   -0.16
#
# [84 rows x 8 columns]

# %%
red_areas, blue_areas = find_successive_bar_areas(df60, 'macd_bar')
blue_areas
# Out:
# [(0, 3), (8, 26), (57, 68), (80, 83)]

# %%
red_areas
# Out:
# [(0, 0), (4, 7), (27, 56), (69, 79)]

# %%
df_red = do_bar_wave_tag(df60, 'macd_bar', red_areas)
df_red[df_red._macd_bar_tag!=0].index
# Out:
# Int64Index([27, 34, 35, 42, 43, 46, 56, 69, 72, 79], dtype='int64')

# %%
df_red[df_red._macd_bar_tag!=0]
# Out:
#     macd_bar  _macd_bar_tag
# 27  0.038211              1
# 34  0.204829              2
# 35  0.183636              1
# 42  0.231215              2
# 43  0.196134              1
# 46  0.231123              2
# 56  0.007092              1
# 69  0.114818              1
# 72  0.196852              2
# 79  0.000061              1

# %%
df_blue = do_bar_wave_tag(df60, 'macd_bar', blue_areas)
df_blue['_macd_bar_tag']*=-1
df_blue[df_blue._macd_bar_tag!=0]
# Out:
#     macd_bar  _macd_bar_tag
# 11  0.121233             -1
# 15  0.145927             -2
# 19  0.076177             -1
# 22  0.150923             -2
# 26  0.055677             -1
# 57  0.012928             -1
# 64  0.197670             -2
# 68  0.002656             -1

# %%
df_red = do_bar_wave_tag(df60, 'macd_bar', red_areas)
df_red[df_red._macd_bar_tag!=0]
# Out:
#     macd_bar  _macd_bar_tag
# 27  0.038211              1
# 34  0.204829              2
# 35  0.183636              1
# 42  0.231215              2
# 43  0.196134              1
# 46  0.231123              2
# 56  0.007092              1
# 69  0.114818              1
# 72  0.196852              2
# 79  0.000061              1

# %%
df60['_macd_bar_tag'] = df_red['_macd_bar_tag']|df_blue['_macd_bar_tag']

df60[df60._macd_bar_tag!=0]
# Out:
#          code             time_key  close      diff  macd_bar      ma5  \
# 11  SZ.002405  2019-08-06 15:00:00  14.23 -0.090504 -0.121233  14.0675
# 15  SZ.002405  2019-08-07 15:00:00  13.80 -0.171953 -0.145927  13.9450
# 19  SZ.002405  2019-08-08 15:00:00  13.88 -0.189160 -0.076177  13.8875
# 22  SZ.002405  2019-08-09 14:00:00  13.28 -0.271752 -0.150923  13.5350
# 26  SZ.002405  2019-08-12 14:00:00  13.57 -0.279475 -0.055677  13.3950
# 27  SZ.002405  2019-08-12 15:00:00  13.99 -0.227755  0.038211  13.5650
# 34  SZ.002405  2019-08-14 14:00:00  14.12 -0.030602  0.204829  14.0775
# 35  SZ.002405  2019-08-14 15:00:00  14.01 -0.018245  0.183636  14.1425
# 42  SZ.002405  2019-08-16 14:00:00  14.83  0.191172  0.231215  14.7075
# 43  SZ.002405  2019-08-16 15:00:00  14.64  0.198148  0.196134  14.6975
# 46  SZ.002405  2019-08-19 14:00:00  15.23  0.298543  0.231123  15.0175
# 56  SZ.002405  2019-08-22 10:30:00  15.48  0.312020  0.007092  15.3525
# 57  SZ.002405  2019-08-22 11:30:00  15.35  0.300394 -0.012928  15.3775
# 64  SZ.002405  2019-08-26 10:30:00  14.74  0.113249 -0.197670  14.9775
# 68  SZ.002405  2019-08-27 10:30:00  16.16  0.145114 -0.002656  15.2650
# 69  SZ.002405  2019-08-27 11:30:00  16.27  0.218204  0.114818  15.5725
# 72  SZ.002405  2019-08-28 10:30:00  16.30  0.323899  0.196852  16.1850
# 79  SZ.002405  2019-08-29 15:00:00  16.00  0.317223  0.000061  16.1700
#
#          ma10  em_bar  _macd_bar_tag
# 11  14.471111   -0.40             -1
# 15  14.077778   -0.13             -2
# 19  13.951111   -0.06             -1
# 22  13.732222   -0.20             -2
# 26  13.513333   -0.12             -1
# 27  13.523333    0.04              1
# 34  13.888889    0.19              2
# 35  13.937778    0.20              1
# 42  14.418889    0.29              2
# 43  14.476667    0.22              1
# 46  14.803333    0.21              2
# 56  15.308889    0.04              1
# 57  15.303333    0.07             -1
# 64  15.181111   -0.20             -2
# 68  15.125556    0.14             -1
# 69  15.248889    0.32              1
# 72  15.615556    0.57              2
# 79  16.200000   -0.03              1

# %%
import matplotlib.pyplot as plt

from matplotlib.dates import DateFormatter
# %matplotlib inline

fig, ax = plt.subplots(1,1, figsize=(20, 7))




df60['colors'] = 'r'
df60.loc[df60.macd_bar<0,'colors'] = 'g'

x_red = df60[df60.macd_bar>0].index
y_red = df60[df60.macd_bar>0]['macd_bar']

x_green = df60[df60.macd_bar<=0].index
y_green = df60[df60.macd_bar<=0]['macd_bar']


ax.bar(x_red, y_red, color='r')
ax.bar(x_green, y_green, color='g')
ax.set_xticklabels(df60['time_key'].array)
ax.xaxis.set_tick_params(rotation=90)

ax.set_title("df60")
# Out:
# Text(0.5, 1.0, 'df60')

# %%
colors = tuple(np.where(df60["macd_bar"]>0, 'r', 'g'))

df60['macd_bar'].plot(kind='bar', color= colors, figsize=(20,7) )

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from example.commons import Faker

def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        #.add_yaxis("商家A", Faker.values())
        #.add_yaxis("商家B", Faker.values())
        .add_yaxis("上架C",[-111,38,22,33,22,-10,-50])
        #.set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
    )
    return c

def new_bar(x, y, title) -> Bar:
    items = []
    for idx, value in zip(x,y):
        if value>=0:
            items.append(
            opts.BarItem(
                    name=idx,
                    value=value,
                    itemstyle_opts=opts.ItemStyleOpts(color="red"),
                )
            )
        else:
            items.append(
            opts.BarItem(
                    name=idx,
                    value=value,
                    itemstyle_opts=opts.ItemStyleOpts(color="green"),
                )
            )
            
    c = (
        Bar()
        .add_xaxis(x)
        .add_yaxis(title,items)
        .set_global_opts(title_opts=opts.TitleOpts(title=title, subtitle="-"))
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
#             markpoint_opts=opts.MarkPointOpts(
#                 data=[
#                     opts.MarkPointItem(type_="max", name="最大值"),
#                     opts.MarkPointItem(type_="min", name="最小值"),
#                     #opts.MarkPointItem(type_="average", name="平均值"),
#                 ]
#             ),
        )
    )
    
    return c


b = new_bar(df60['time_key'].tolist(), df60['macd_bar'].tolist(), 'MACD_BAR')
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0aed8c93deca4e769c75c5328a857cd1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0aed8c93deca4e769c75c5328a857cd1 = echarts.init(
#                     document.getElementById('0aed8c93deca4e769c75c5328a857cd1'), 'white', {renderer: 'canvas'});
#                 var option_0aed8c93deca4e769c75c5328a857cd1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "MACD_BAR",
#             "data": [
#                 {
#                     "name": "2019-08-02 10:30:00",
#                     "value": 0.0,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-08-02 11:30:00",
#                     "value": -0.01659259259259045,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-02 14:00:00",
#                     "value": -0.018426759523054555,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-02 15:00:00",
#                     "value": -0.01725424917486191,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-05 10:30:00",
#                     "value": 0.062361845817880776,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-08-05 11:30:00",
#                     "value": 0.08216814878007743,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-08-05 14:00:00",
#                     "value": 0.07347210205496142,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-08-05 15:00:00",
#                     "value": 0.0471997380845187,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },
#                 {
#                     "name": "2019-08-06 10:30:00",
#                     "value": -0.06540065462491224,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-06 11:30:00",
#                     "value": -0.13288423415207498,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-06 14:00:00",
#                     "value": -0.1325111066971279,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-06 15:00:00",
#                     "value": -0.12123308215884472,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-07 10:30:00",
#                     "value": -0.13151474943664387,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-07 11:30:00",
#                     "value": -0.14043099711921653,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-07 14:00:00",
#                     "value": -0.13494041840291593,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-07 15:00:00",
#                     "value": -0.14592725423335914,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-08 10:30:00",
#                     "value": -0.12931902344731938,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-08 11:30:00",
#                     "value": -0.11641227862162395,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-08 14:00:00",
#                     "value": -0.09474963975937667,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-08 15:00:00",
#                     "value": -0.07617673353307619,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-09 10:30:00",
#                     "value": -0.08076206453652751,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-09 11:30:00",
#                     "value": -0.1300705649088018,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-09 14:00:00",
#                     "value": -0.1509225536068921,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-09 15:00:00",
#                     "value": -0.14867241352079558,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-12 10:30:00",
#                     "value": -0.130445054956766,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-12 11:30:00",
#                     "value": -0.10796709607498356,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-12 14:00:00",
#                     "value": -0.05567742407826914,
#                     "itemStyle": {
#                         "color": "green"
#                     }
#                 },
#                 {
#                     "name": "2019-08-12 15:00:00",
#                     "value": 0.038210506778301234,
#                     "itemStyle": {
#                         "color": "red"
#                     }
#                 },

# %%
df60.shape[0]
# Out:
# 84
