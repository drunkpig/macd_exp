# %%
from futu import *
import pandas as pd
import numpy as np

# %%
quote_ctx = OpenQuoteContext(host='futuapi.mkmerich.com', port=54012)
ret, data, page_req_key = quote_ctx.request_history_kline('SH.601127', start='2019-01-01', end='2019-07-26',
                                                          ktype=KLType.K_60M, fields=[KL_FIELD.DATE_TIME, KL_FIELD.CLOSE], max_count=50)
# Out:
# 2019-07-29 09:15:40,513 [open_context_base.py] _socket_reconnect_and_wait_ready:256: Start connecting: host=futuapi.mkmerich.com; port=54012;
# 2019-07-29 09:15:41,135 [open_context_base.py] on_connected:344: Connected : conn_id=11;
# 2019-07-29 09:15:41,189 [open_context_base.py] _handle_init_connect:444: InitConnect ok: conn_id=11; info={'server_version': 203, 'login_user_id': 1509176, 'conn_id': 6561413734177839042, 'conn_key': 'B98F120207D30E5B', 'keep_alive_interval': 10, 'is_encrypt': False};

# %%
data
# Out:
#          code             time_key  close
# 0   SH.601127  2019-01-02 10:30:00  16.57
# 1   SH.601127  2019-01-02 11:30:00  16.54
# 2   SH.601127  2019-01-02 14:00:00  16.62
# 3   SH.601127  2019-01-02 15:00:00  16.62
# 4   SH.601127  2019-01-03 10:30:00  16.45
# 5   SH.601127  2019-01-03 11:30:00  16.07
# 6   SH.601127  2019-01-03 14:00:00  15.96
# 7   SH.601127  2019-01-03 15:00:00  16.00
# 8   SH.601127  2019-01-04 10:30:00  16.09
# 9   SH.601127  2019-01-04 11:30:00  16.16
# 10  SH.601127  2019-01-04 14:00:00  16.13
# 11  SH.601127  2019-01-04 15:00:00  16.12
# 12  SH.601127  2019-01-07 10:30:00  16.21
# 13  SH.601127  2019-01-07 11:30:00  16.16
# 14  SH.601127  2019-01-07 14:00:00  16.12
# 15  SH.601127  2019-01-07 15:00:00  16.12
# 16  SH.601127  2019-01-08 10:30:00  16.12
# 17  SH.601127  2019-01-08 11:30:00  16.22
# 18  SH.601127  2019-01-08 14:00:00  16.18
# 19  SH.601127  2019-01-08 15:00:00  16.29
# 20  SH.601127  2019-01-09 10:30:00  16.63
# ...
