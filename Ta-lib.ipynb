# %%
import pandas as pd
from macdlib import *
import matplotlib.pyplot as plt
# %matplotlib inline

STOCK_CODE='SZ.002405'
#prepare_csv_data([STOCK_CODE],n_days=90)
compute_df_bar([STOCK_CODE])
fname = df_file_name(STOCK_CODE, KLType.K_60M)
df60 = pd.read_csv(fname, index_col=0)

df60
# Out:
#           code             time_key  close   high    low  macd_bar     ma5  \
# 0    SZ.002405  2019-06-24 10:30:00  16.29  16.61  16.22       NaN     NaN
# 1    SZ.002405  2019-06-24 11:30:00  16.13  16.35  16.09       NaN     NaN
# 2    SZ.002405  2019-06-24 14:00:00  16.16  16.20  16.10       NaN     NaN
# 3    SZ.002405  2019-06-24 15:00:00  16.25  16.34  16.12       NaN     NaN
# 4    SZ.002405  2019-06-25 10:30:00  16.11  16.17  15.88       NaN  16.188
# 5    SZ.002405  2019-06-25 11:30:00  15.71  16.14  15.70       NaN  16.072
# 6    SZ.002405  2019-06-25 14:00:00  15.90  15.99  15.65       NaN  16.026
# 7    SZ.002405  2019-06-25 15:00:00  15.97  16.06  15.85       NaN  15.988
# 8    SZ.002405  2019-06-26 10:30:00  16.07  16.17  15.78       NaN  15.952
# 9    SZ.002405  2019-06-26 11:30:00  16.20  16.50  16.05       NaN  15.970
# 10   SZ.002405  2019-06-26 14:00:00  16.14  16.24  16.10       NaN  16.056
# ...

# %%
import talib
# %time diff, macdsignal, macd_bar = talib.MACD(df60['close'], fastperiod=12, slowperiod=26, signalperiod=9)
df60['macd_bar2']=macd_bar
# Out:
# Wall time: 3 ms

# %%
colors = tuple(np.where(df60["macd_bar"]>0, 'r', 'g'))

df60['macd_bar'].plot(kind='bar', color= colors, figsize=(20,7) )

# %%
colors = tuple(np.where(df60["macd_bar2"]>0, 'r', 'g'))

df60['macd_bar2'].plot(kind='bar', color= colors, figsize=(20,7) )

# %%
import talib

high=df60['high']
low = df60['low']
close=df60['close']
real = talib.ATR(high, low, close, timeperiod=14)
real
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14     0.287143
# 15     0.282347
# 16     0.292894
# 17     0.288401
# 18     0.277801
# 19     0.273672
# 20     0.311267
# 21     0.304034
# 22     0.293031
# 23     0.312815
# 24     0.316185
# 25     0.312172
# 26     0.302017
# 27     0.299016
# 28     0.308372
# 29     0.299917
#          ...
# 226    0.343006
# 227    0.334934
# 228    0.332439
# 229    0.324408
# 230    0.325522
# 231    0.314413
# 232    0.314812
# 233    0.319468
# 234    0.315935
# 235    0.306225
# 236    0.306495
# 237    0.296031
# 238    0.282743
# 239    0.286118
# 240    0.318539
# 241    0.325072
# 242    0.330424
# 243    0.331108
# 244    0.353171
# 245    0.345088
# 246    0.354010
# 247    0.355152
# 248    0.353356
# 249    0.342402
# ...

# %%
df_xkgf = get_df_of_code("SH.601127")
df_xkgf
# Out:
# 2019-09-22 20:06:47,783 [open_context_base.py] _socket_reconnect_and_wait_ready:256: Start connecting: host=cxu-pc; port=11111;
# 2019-09-22 20:06:47,788 [open_context_base.py] on_connected:344: Connected : conn_id=3;
# 2019-09-22 20:06:47,809 [open_context_base.py] _handle_init_connect:444: InitConnect ok: conn_id=3; info={'server_version': 203, 'login_user_id': 1509176, 'conn_id': 6581508934419040517, 'conn_key': '067B176A8137565B', 'keep_alive_interval': 10, 'is_encrypt': False};
#          code             time_key  close   high    low
# 0   SH.601127  2019-08-23 10:30:00  13.14  13.33  13.13
# 1   SH.601127  2019-08-23 11:30:00  13.16  13.25  13.09
# 2   SH.601127  2019-08-23 14:00:00  13.09  13.19  13.08
# 3   SH.601127  2019-08-23 15:00:00  13.11  13.14  13.09
# 4   SH.601127  2019-08-26 10:30:00  12.94  13.11  12.89
# 5   SH.601127  2019-08-26 11:30:00  12.86  12.96  12.77
# 6   SH.601127  2019-08-26 14:00:00  12.77  12.93  12.75
# ...

# %%
df_tlwl = get_df_of_code("SH.600125")
df_tlwl
# Out:
# 2019-09-22 20:07:22,048 [open_context_base.py] _socket_reconnect_and_wait_ready:256: Start connecting: host=cxu-pc; port=11111;
# 2019-09-22 20:07:22,053 [open_context_base.py] on_connected:344: Connected : conn_id=4;
# 2019-09-22 20:07:22,073 [open_context_base.py] _handle_init_connect:444: InitConnect ok: conn_id=4; info={'server_version': 203, 'login_user_id': 1509176, 'conn_id': 6581509078142802119, 'conn_key': '0D9683E0A237565B', 'keep_alive_interval': 10, 'is_encrypt': False};
#          code             time_key  close  high   low
# 0   SH.600125  2019-08-23 10:30:00   6.03  6.07  6.02
# 1   SH.600125  2019-08-23 11:30:00   6.04  6.05  6.03
# 2   SH.600125  2019-08-23 14:00:00   6.00  6.04  6.00
# 3   SH.600125  2019-08-23 15:00:00   6.00  6.02  5.99
# 4   SH.600125  2019-08-26 10:30:00   5.89  5.91  5.87
# 5   SH.600125  2019-08-26 11:30:00   5.94  5.95  5.89
# 6   SH.600125  2019-08-26 14:00:00   5.92  5.95  5.91
# 7   SH.600125  2019-08-26 15:00:00   5.92  5.94  5.89
# ...

# %%
atr_xkgf = talib.ATR(df_xkgf['high'], df_xkgf['low'], df_xkgf['close'], timeperiod=14)
atr_tlwl = talib.ATR(df_tlwl['high'], df_tlwl['low'], df_tlwl['close'], timeperiod=14)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14    0.052143
# 15    0.049847
# 16    0.052001
# 17    0.051858
# 18    0.050297
# 19    0.049561
# 20    0.049592
# 21    0.050336
# 22    0.049598
# 23    0.051055
# 24    0.053837
# 25    0.054277
# 26    0.053257
# 27    0.050882
# 28    0.050104
# 29    0.047954
#         ...
# 50    0.047805
# 51    0.048676
# 52    0.049485
# 53    0.047379
# 54    0.047566
# 55    0.046311
# 56    0.045860
# 57    0.045442
# 58    0.043624
# 59    0.042651
# 60    0.043890
# 61    0.043613
# 62    0.044069
# 63    0.044492
# 64    0.047743
# 65    0.048619
# 66    0.048003
# 67    0.048860
# 68    0.054656
# 69    0.054323
# 70    0.054014
# 71    0.053728
# 72    0.054890
# 73    0.053112
# 74    0.051461
# 75    0.050642
# 76    0.070597
# 77    0.069840
# ...

# %%
df_tlwl = get_df_of_code("SZ.002405")
atr = talib.ATR(df_tlwl['high'], df_tlwl['low'], df_tlwl['close'], timeperiod=14)

atr
# Out:
# 2019-09-22 20:26:02,996 [open_context_base.py] _socket_reconnect_and_wait_ready:256: Start connecting: host=cxu-pc; port=11111;
# 2019-09-22 20:26:03,002 [open_context_base.py] on_connected:344: Connected : conn_id=9;
# 2019-09-22 20:26:03,044 [open_context_base.py] _handle_init_connect:444: InitConnect ok: conn_id=9; info={'server_version': 203, 'login_user_id': 1509176, 'conn_id': 6581513779722990094, 'conn_key': 'BB22B68CE93B565B', 'keep_alive_interval': 10, 'is_encrypt': False};
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14    0.387143
# 15    0.378061
# 16    0.376771
# 17    0.366287
# 18    0.363696
# 19    0.357003
# 20    0.356503
# 21    0.351038
# 22    0.355964
# 23    0.348395
# 24    0.354938
# 25    0.343157
# 26    0.337932
# 27    0.330937
# 28    0.342298
# 29    0.335705
# ...
